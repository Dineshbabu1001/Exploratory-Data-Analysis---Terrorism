# %%
import pandas as pd
import numpy as np
import plotly.graph_objects as go
import plotly.express as px
import plotly.colors as colors
import warnings
warnings.filterwarnings("ignore")

# %%
data = pd.read_csv("/content/global_terrorism.csv", encoding='latin1')

# %%
data.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  1.970000e+11   1970       7     2        NaN         0        NaN       58
# 1  1.970000e+11   1970       0     0        NaN         0        NaN      130
# 2  1.970010e+11   1970       1     0        NaN         0        NaN      160
# 3  1.970010e+11   1970       1     0        NaN         0        NaN       78
# 4  1.970010e+11   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
# ...

# %%
data.columns.values
# Out:
# array(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region', 'region_txt',
#        'provstate', 'city', 'latitude', 'longitude', 'specificity',
#        'vicinity', 'location', 'summary', 'crit1', 'crit2', 'crit3',
#        'doubtterr', 'alternative', 'alternative_txt', 'multiple',
#        'success', 'suicide', 'attacktype1', 'attacktype1_txt',
#        'attacktype2', 'attacktype2_txt', 'attacktype3', 'attacktype3_txt',
#        'targtype1', 'targtype1_txt', 'targsubtype1', 'targsubtype1_txt',
#        'corp1', 'target1', 'natlty1', 'natlty1_txt', 'targtype2',
#        'targtype2_txt', 'targsubtype2', 'targsubtype2_txt', 'corp2',
#        'target2', 'natlty2', 'natlty2_txt', 'targtype3', 'targtype3_txt',
#        'targsubtype3', 'targsubtype3_txt', 'corp3', 'target3', 'natlty3',
#        'natlty3_txt', 'gname', 'gsubname', 'gname2', 'gsubname2',
# ...

# %%
data.rename(columns={'iyear':'Year',
                     'imonth':'Month',
                     'iday':"day",
                     'gname':'Group',
                     'country_txt':'Country',
                     'region_txt':'Region',
                     'provstate':'State',
                     'city':'City',
                     'latitude':'latitude',
                     'longitude':'longitude',
                     'summary':'summary',
                     'attacktype1_txt':'Attacktype',
                     'targtype1_txt':'Targettype',
                     'weaptype1_txt':'Weapon',
                     'nkill':'kill',
                     'nwound':'Wound'},inplace=True)

# %%
data = data[['Year','Month',
             'day','Country',
             'State','Region',
             'City','latitude',
             'longitude',"Attacktype",
             'kill','Wound',
             'target1','summary',
             'Group','Targettype',
             'Weapon','motive']]

# %%
data.head()
# Out:
#    Year  Month  day             Country    State                       Region  \
# 0  1970      7    2  Dominican Republic      NaN  Central America & Caribbean
# 1  1970      0    0              Mexico  Federal                North America
# 2  1970      1    0         Philippines   Tarlac               Southeast Asia
# 3  1970      1    0              Greece   Attica               Western Europe
# 4  1970      1    0               Japan  Fukouka                    East Asia
#
#             City   latitude   longitude                      Attacktype  kill  \
# 0  Santo Domingo  18.456792  -69.951164                   Assassination   1.0
# 1    Mexico city  19.371887  -99.086624     Hostage Taking (Kidnapping)   0.0
# 2        Unknown  15.478598  120.599741                   Assassination   1.0
# 3         Athens  37.997490   23.762728               Bombing/Explosion   NaN
# 4        Fukouka  33.580412  130.396361  Facility/Infrastructure Attack   NaN
#
# ...

# %%
data.shape
# Out:
# (181691, 18)

# %%
data.isnull().sum()
# Out:
# Year               0
# Month              0
# day                0
# Country            0
# State            421
# Region             0
# City             434
# latitude        4556
# longitude       4557
# Attacktype         0
# kill           10313
# Wound          16311
# target1          636
# summary        66129
# Group              0
# Targettype         0
# Weapon             0
# motive        131130
# dtype: int64

# %%
data['Wound'] = data['Wound'].fillna(0)
data['kill'] = data['kill'].fillna(0)

# %%
data['Casualities'] = data['kill'] + data['Wound']

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Data columns (total 19 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Year         181691 non-null  int64
#  1   Month        181691 non-null  int64
#  2   day          181691 non-null  int64
#  3   Country      181691 non-null  object
#  4   State        181270 non-null  object
#  5   Region       181691 non-null  object
#  6   City         181257 non-null  object
#  7   latitude     177135 non-null  float64
#  8   longitude    177134 non-null  float64
#  9   Attacktype   181691 non-null  object
#  10  kill         181691 non-null  float64
#  11  Wound        181691 non-null  float64
#  12  target1      181055 non-null  object
#  13  summary      115562 non-null  object
#  14  Group        181691 non-null  object
#  15  Targettype   181691 non-null  object
#  16  Weapon       181691 non-null  object
#  17  motive       50561 non-null   object
# ...

# %%
data.describe()
# Out:
#                 Year          Month            day       latitude  \
# count  181691.000000  181691.000000  181691.000000  177135.000000
# mean     2002.638997       6.467277      15.505644      23.498343
# std        13.259430       3.388303       8.814045      18.569242
# min      1970.000000       0.000000       0.000000     -53.154613
# 25%      1991.000000       4.000000       8.000000      11.510046
# 50%      2009.000000       6.000000      15.000000      31.467463
# 75%      2014.000000       9.000000      23.000000      34.685087
# max      2017.000000      12.000000      31.000000      74.633553
#
#           longitude           kill          Wound    Casualities
# count  1.771340e+05  181691.000000  181691.000000  181691.000000
# mean  -4.586957e+02       2.266860       2.883296       5.150156
# std    2.047790e+05      11.227057      34.309747      40.555416
# min   -8.618590e+07       0.000000       0.000000       0.000000
# ...

# %%
years_count = data['Year'].value_counts().sort_index()

# %%
fig = px.bar(x=years_count.index,
             y=years_count.values,
             labels={'x': 'Year', 'y': 'Number of Attacks'},
             title='Number of Terrorist Attacks Each Year')

fig.update_layout(xaxis=dict(tickangle=45))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
cross_tab = pd.crosstab(data['Year'], data['Region'])

# %%
cross_tab = cross_tab.reset_index()

# %%
fig = px.area(cross_tab,
              x='Year',
              y=cross_tab.columns[1:],
              title='Terrorist Activities By Region In Each Year',
              labels={'Year': 'Year', 'value': 'Number of Attacks', 'variable': 'Region'})

# %%
fig.update_layout(
    xaxis=dict(title=dict(text='Year', font=dict(size=20))),
    yaxis=dict(title=dict(text='Number of Attacks', font=dict(size=20))),
    font=dict(size=20))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
attack = data.Country.value_counts()[:10]
attack
# Out:
# Iraq              24636
# Pakistan          14368
# Afghanistan       12731
# India             11960
# Colombia           8306
# Philippines        6908
# Peru               6096
# El Salvador        5320
# United Kingdom     5235
# Turkey             4292
# Name: Country, dtype: int64

# %%
data.Group.value_counts()[1:10]
# Out:
# Taliban                                             7478
# Islamic State of Iraq and the Levant (ISIL)         5613
# Shining Path (SL)                                   4555
# Farabundo Marti National Liberation Front (FMLN)    3351
# Al-Shabaab                                          3288
# New People's Army (NPA)                             2772
# Irish Republican Army (IRA)                         2671
# Revolutionary Armed Forces of Colombia (FARC)       2487
# Boko Haram                                          2418
# Name: Group, dtype: int64

# %%
fig = px.bar(data_frame=data['Country'].value_counts()[:10],
             x=data['Country'].value_counts()[:10].index,
             y=data['Country'].value_counts()[:10].values,
             color=data['Country'].value_counts()[:10].index,
             color_discrete_sequence=px.colors.sequential.YlOrBr_r,
             labels={'x': 'Countries', 'y': 'Count'},
             title='Top Countries Affected',
             height=500,
             width=800)
fig.update_xaxes(tickangle=45)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df = data[['Year', 'kill']].groupby(['Year']).sum().reset_index()

fig = px.bar(df,
             x='Year',
             y='kill',
             labels={'Year': 'Year', 'kill': 'Number of killed people'},
             title="People Died Due To Attack",
             height=500, width=800)

fig.update_xaxes(tickangle=45,
                 showline=True,
                 linewidth=1,
                 linecolor='black')
fig.update_yaxes(showline=True,
                 linewidth=1,
                 linecolor='black')
fig.update_layout(xaxis_title="Year",
                  yaxis_title="Number of killed people")

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
city_counts = data['City'].value_counts().to_frame().sort_values('City', axis=0, ascending=False).head(10)

fig = px.bar(city_counts,
             x=city_counts.index,
             y='City',
             labels={'x': 'City', 'City': 'Number of attacks'},
             color='City',
             color_continuous_scale='Blues',
             title='Top 10 most affected cities',
             height=500, width=800)

fig.update_xaxes(tickangle=45)
fig.update_layout(xaxis_title="City", yaxis_title="Number of attacks")

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
attacktype_counts = data['Attacktype'].value_counts()

fig = px.bar(attacktype_counts,
             x=attacktype_counts.index,
             y=attacktype_counts.values,
             labels={'x': 'Attack Type', 'y': 'Number of Attacks'},
             color=attacktype_counts.index,
             color_discrete_sequence=px.colors.qualitative.Dark2,
             title='Name of Attack Types',
             height=500, width=800)

fig.update_xaxes(tickangle=45)
fig.update_layout(xaxis_title="Attack Type", yaxis_title="Number of Attacks")

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
kill_by_attacktype = data[['Attacktype', 'kill']].groupby(["Attacktype"], axis=0).sum()

fig = px.bar(kill_by_attacktype,
             x=kill_by_attacktype.index,
             y='kill',
             labels={'x': 'Attack Type', 'kill': 'Number of People Killed'},
             color=kill_by_attacktype.index,
             title='Number of People Killed by Attack Type',
             height=500, width=800)

fig.update_xaxes(tickangle=45)
fig.update_layout(xaxis_title="Attack Type", yaxis_title="Number of People Killed")

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
wound_by_attacktype = data[['Attacktype', 'Wound']].groupby(["Attacktype"], axis=0).sum()

fig = px.bar(wound_by_attacktype,
             x=wound_by_attacktype.index,
             y='Wound',
             labels={'x': 'Attack Type', 'Wound': 'Number of People Wounded'},
             color=wound_by_attacktype.index,
             title='Number of People Wounded by Attack Type',
             height=500, width=800)

fig.update_xaxes(tickangle=45)
fig.update_layout(xaxis_title="Attack Type", yaxis_title="Number of People Wounded")

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
targettype_counts = data['Targettype'].value_counts()

fig = px.bar(targettype_counts,
             x=targettype_counts.index,
             y=targettype_counts.values,
             labels={'x': 'Target Type', 'y': 'Count'},
             color=targettype_counts.index,
             title='Number of Attacks by Target Type',
             height=500, width=800)

fig.update_xaxes(tickangle=90)
fig.update_layout(xaxis_title="Target Type", yaxis_title="Count")

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
group_counts = data['Group'].value_counts().to_frame().drop('Unknown').head(10)

fig = px.bar(group_counts,
             x=group_counts.index,
             y='Group',
             labels={'x': 'Terrorist Group Name', 'Group': 'Attack Number'},
             color=group_counts.index,
             title='Top 10 Terrorist Group Attacks',
             height=500, width=800)

fig.update_xaxes(tickangle=45)
fig.update_layout(xaxis_title="Terrorist Group Name",
                  yaxis_title="Attack Number")

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
group_kill = data[['Group', 'kill']].groupby(['Group'], axis=0).sum().drop('Unknown').sort_values('kill', ascending=False).head(10)

fig = px.bar(group_kill,
             x=group_kill.index,
             y='kill',
             labels={'x': 'Terrorist Group Name', 'kill': 'Number of Killed People'},
             color=group_kill.index,
             title='Top 10 Terrorist Group Attacks (by Number of Killed People)',
             height=500, width=800)

fig.update_xaxes(tickangle=45)
fig.update_layout(xaxis_title="Terrorist Group Name",
                  yaxis_title="Number of Killed People")

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df=data[['Group','Country','kill']]
df=df.groupby(['Group','Country'],axis=0).sum().sort_values('kill',ascending=False).drop('Unknown').reset_index().head(10)
df
# Out:
#                                               Group      Country     kill
# 0       Islamic State of Iraq and the Levant (ISIL)         Iraq  31058.0
# 1                                           Taliban  Afghanistan  29269.0
# 2                                        Boko Haram      Nigeria  16917.0
# 3                                 Shining Path (SL)         Peru  11595.0
# 4           Liberation Tigers of Tamil Eelam (LTTE)    Sri Lanka  10928.0
# 5                                        Al-Shabaab      Somalia   8176.0
# 6  Farabundo Marti National Liberation Front (FMLN)  El Salvador   8019.0
# 7       Islamic State of Iraq and the Levant (ISIL)        Syria   6883.0
# 8                 Nicaraguan Democratic Force (FDN)    Nicaragua   6630.0
# 9                   Tehrik-i-Taliban Pakistan (TTP)     Pakistan   6014.0

# %%
fig = px.bar(df, x='Country',
             y='kill',
             color='Group',
             labels={'Country': 'Country', 'kill': 'Number of Kills'},
             title='Number of Kills by Top 10 Terrorist Groups and Countries',
             height=500, width=800)

fig.update_xaxes(tickangle=45)
fig.update_layout(xaxis_title="Country",
                  yaxis_title="Number of Kills")

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
kill = data.loc[:,'kill']
print('Number of people killed by terror attack:', int(sum(kill.dropna())))
# Out:
# Number of people killed by terror attack: 411868

# %%
typeKill = data.groupby('Attacktype')['kill'].sum().reset_index()
typeKill
# Out:
#                             Attacktype      kill
# 0                        Armed Assault  160297.0
# 1                        Assassination   24920.0
# 2                    Bombing/Explosion  157321.0
# 3       Facility/Infrastructure Attack    3642.0
# 4                            Hijacking    3718.0
# 5  Hostage Taking (Barricade Incident)    4478.0
# 6          Hostage Taking (Kidnapping)   24231.0
# 7                      Unarmed Assault     880.0
# 8                              Unknown   32381.0

# %%
fig = px.bar(typeKill,
             x='Attacktype',
             y='kill',
             labels={'Attacktype': 'Attack Type', 'kill': 'Number of Kills'},
             title='Number of Kills by Attack Type',
             height=500, width=800)

fig.update_xaxes(tickangle=45)
fig.update_layout(xaxis_title="Attack Type", yaxis_title="Number of Kills")

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
countryKill = data.groupby('Country')['kill'].sum().reset_index()
countryKill
# Out:
#          Country     kill
# 0    Afghanistan  39384.0
# 1        Albania     42.0
# 2        Algeria  11066.0
# 3        Andorra      0.0
# 4         Angola   3043.0
# ..           ...      ...
# 200        Yemen   8776.0
# 201   Yugoslavia    119.0
# 202        Zaire    324.0
# 203       Zambia     70.0
# 204     Zimbabwe    154.0
#
# [205 rows x 2 columns]

# %%
fig_1 = px.choropleth(df,
                    locations='Country',
                    color='kill',
                    locationmode='country names',
                    color_continuous_scale='Viridis')

fig_1.update_layout(title='Total Kills by Country',
                  geo=dict(showframe=False,
                           showcoastlines=False,
                           projection_type='equirectangular'))
fig_1.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ##***Conclusion :***
#
# *   Iraq emerges as the unfortunate leader in recorded attacks, with Baghdad standing resilient as its most targeted city.
# *   The tumultuous Middle East & North Africa region becomes a focal point of unrest, painting a vivid backdrop of conflict.
# *   Amidst the calendar's pages, the seemingly serene fifth month unfurls as the peak of aggression, bearing witness to the highest number of attacks.
# *   The Taliban, a haunting presence, takes center stage in this unsettling narrative, a stark emblem of aggression.
# *   Bombings and explosions reverberate as the prevalent instruments of destruction, leaving scars on both land and spirit.
# *   Behind these stark statistics lie tales of human endurance and hope, urging us to collectively strive for a future devoid of such disquieting conclusions.
